# %%
pip install rpy2
# Out:
# ...
#   WARNING: The script cffi-gen-src is installed in '/Library/Frameworks/Python.framework/Versions/3.13/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr


base = importr('base')
ggplot2 = importr('ggplot2')
stats = importr('stats')
datos = stats.rnorm(100)
#print(datos)

# %%
e=base.data_frame(Distribucion=datos)
print(e)
# Out:
#     Distribucion
# 1    2.003509154
# 2    1.040788083
# 3   -0.916447789
# 4    0.298551179
# 5   -0.674873734
# 6   -2.539206593
# 7   -0.825243841
# 8   -0.872897861
# 9    0.327042150
# 10  -0.949117245
# 11  -1.059642637
# 12   0.880117669
# 13  -0.879797655
# 14  -0.890507740
# 15   0.721341747
# 16  -0.949390905
# 17  -0.007629112
# 18   1.174389671
# 19  -0.533476953
# 20   1.854182050
# 21   0.624792744
# 22  -1.439594164
# 23  -0.605504404
# 24   1.736343730
# 25   0.920402845
# 26   1.064136252
# 27   0.427766036
# 28   1.599350550
# 29   1.364553512
# 30   0.986942431
# 31  -0.513842621
# 32   0.290319372
# 33  -0.198948766
# 34   0.727483464
# 35   0.306083901
# 36  -1.011427039
# 37  -0.348406975
# 38   1.917053564
# 39   0.430917335
# 40  -0.568470681
# 41  -0.623594094
# 42  -0.114181108
# 43   0.258258710
# 44  -1.243996500
# 45   1.050816663
# 46   0.523330315
# 47  -0.245605938
# 48   0.954535994
# 49   0.515328708
# 50  -0.254584363
# 51  -0.109887699
# ...

# %%
reshape=importr('reshape2')
